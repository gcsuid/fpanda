# %%
import pandas as pd

# %%
df = pd.read_csv('survey_results_public.csv')

# %%
df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88878       88377                                                NaN      Yes
# 88879       88601                                                NaN       No
# 88880       88802                                                NaN       No
# 88881       88816                                                NaN       No
# 88882       88863                                                NaN      Yes
#
# ...

# %%
df.shape
# Out:
# (88883, 85)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88883 entries, 0 to 88882
# Data columns (total 85 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Respondent              88883 non-null  int64
#  1   MainBranch              88331 non-null  object
#  2   Hobbyist                88883 non-null  object
#  3   OpenSourcer             88883 non-null  object
#  4   OpenSource              86842 non-null  object
#  5   Employment              87181 non-null  object
#  6   Country                 88751 non-null  object
#  7   Student                 87014 non-null  object
#  8   EdLevel                 86390 non-null  object
#  9   UndergradMajor          75614 non-null  object
#  10  EduOther                84260 non-null  object
#  11  OrgSize                 71791 non-null  object
#  12  DevType                 81335 non-null  object
#  13  YearsCode               87938 non-null  object
# ...

# %%
pd.set_option('display.max_columns',85)

# %%
schema_df = pd.read_csv('survey_results_schema.csv')

# %%
schema_df
# Out:
#           Column                                       QuestionText
# 0     Respondent  Randomized respondent ID number (not in order ...
# 1     MainBranch  Which of the following options best describes ...
# 2       Hobbyist                            Do you code as a hobby?
# 3    OpenSourcer        How often do you contribute to open source?
# 4     OpenSource  How do you feel about the quality of open sour...
# ..           ...                                                ...
# 80     Sexuality  Which of the following do you currently identi...
# 81     Ethnicity  Which of the following do you identify as? Ple...
# 82    Dependents  Do you have any dependents (e.g., children, el...
# 83  SurveyLength  How do you feel about the length of the survey...
# 84    SurveyEase  How easy or difficult was this survey to compl...
#
# [85 rows x 2 columns]

# %%
df.head()
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1             I am a student who is learning to code      Yes
# 1           2             I am a student who is learning to code       No
# 2           3  I am not primarily a developer, but I write co...      Yes
# 3           4                     I am a developer by profession       No
# 4           5                     I am a developer by profession      Yes
#
#                   OpenSourcer  \
# 0                       Never
# 1     Less than once per year
# 2                       Never
# 3                       Never
# 4  Once a month or more often
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
# 1  The quality of OSS and closed source software ...
# 2  The quality of OSS and closed source software ...
# 3  The quality of OSS and closed source software ...
# 4  OSS is, on average, of HIGHER quality than pro...
#
# ...

# %%
df.tail()
# Out:
#        Respondent MainBranch Hobbyist  \
# 88878       88377        NaN      Yes
# 88879       88601        NaN       No
# 88880       88802        NaN       No
# 88881       88816        NaN       No
# 88882       88863        NaN      Yes
#
#                                              OpenSourcer  \
# 88878  Less than once a month but more than once per ...
# 88879                                              Never
# 88880                                              Never
# 88881                                              Never
# 88882                            Less than once per year
#
#                                               OpenSource  \
# 88878  The quality of OSS and closed source software ...
# 88879  The quality of OSS and closed source software ...
# 88880                                                NaN
# 88881  OSS is, on average, of HIGHER quality than pro...
# 88882  OSS is, on average, of HIGHER quality than pro...
#
# ...

# %%
#if a python dictionary has key-value pair then it can be converted to dataframe 
#series is all rows of a particular column
mb = df['MainBranch']
print(mb)
# Out:
# 0                   I am a student who is learning to code
# 1                   I am a student who is learning to code
# 2        I am not primarily a developer, but I write co...
# 3                           I am a developer by profession
# 4                           I am a developer by profession
#                                ...
# 88878                                                  NaN
# 88879                                                  NaN
# 88880                                                  NaN
# 88881                                                  NaN
# 88882                                                  NaN
# Name: MainBranch, Length: 88883, dtype: object

# %%
type(mb)
# Out:
# pandas.core.series.Series

# %%
df.MainBranch
#same result as above
# Out:
# 0                   I am a student who is learning to code
# 1                   I am a student who is learning to code
# 2        I am not primarily a developer, but I write co...
# 3                           I am a developer by profession
# 4                           I am a developer by profession
#                                ...
# 88878                                                  NaN
# 88879                                                  NaN
# 88880                                                  NaN
# 88881                                                  NaN
# 88882                                                  NaN
# Name: MainBranch, Length: 88883, dtype: object

# %%
df[['MainBranch','Hobbyist']]
# Out:
#                                               MainBranch Hobbyist
# 0                 I am a student who is learning to code      Yes
# 1                 I am a student who is learning to code       No
# 2      I am not primarily a developer, but I write co...      Yes
# 3                         I am a developer by profession       No
# 4                         I am a developer by profession      Yes
# ...                                                  ...      ...
# 88878                                                NaN      Yes
# 88879                                                NaN       No
# 88880                                                NaN       No
# 88881                                                NaN       No
# 88882                                                NaN      Yes
#
# [88883 rows x 2 columns]

# %%
df.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource',
#        'Employment', 'Country', 'Student', 'EdLevel', 'UndergradMajor',
#        'EduOther', 'OrgSize', 'DevType', 'YearsCode', 'Age1stCode',
#        'YearsCodePro', 'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney',
#        'MgrWant', 'JobSeek', 'LastHireDate', 'LastInt', 'FizzBuzz',
#        'JobFactors', 'ResumeUpdate', 'CurrencySymbol', 'CurrencyDesc',
#        'CompTotal', 'CompFreq', 'ConvertedComp', 'WorkWeekHrs', 'WorkPlan',
#        'WorkChallenge', 'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev',
#        'CodeRevHrs', 'UnitTests', 'PurchaseHow', 'PurchaseWhat',
#        'LanguageWorkedWith', 'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %%
#integer location
#above returns only columns, the function used here also returns the rows.
df.iloc(0)
df.iloc[1]
# Out:
# Respondent                                                      2
# MainBranch                 I am a student who is learning to code
# Hobbyist                                                       No
# OpenSourcer                               Less than once per year
# OpenSource      The quality of OSS and closed source software ...
#                                       ...
# Sexuality                                 Straight / Heterosexual
# Ethnicity                                                     NaN
# Dependents                                                     No
# SurveyLength                                Appropriate in length
# SurveyEase                             Neither easy nor difficult
# Name: 1, Length: 85, dtype: object

# %%
#like columns, you can also do multiple rows

df.iloc[0,1]
# Out:
# 'I am a student who is learning to code'

# %%
df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88878       88377                                                NaN      Yes
# 88879       88601                                                NaN       No
# 88880       88802                                                NaN       No
# 88881       88816                                                NaN       No
# 88882       88863                                                NaN      Yes
#
# ...

# %%
#see the use the index or the side and pass the number
df.loc[0]
# Out:
# Respondent                                                      1
# MainBranch                 I am a student who is learning to code
# Hobbyist                                                      Yes
# OpenSourcer                                                 Never
# OpenSource      The quality of OSS and closed source software ...
#                                       ...
# Sexuality                                 Straight / Heterosexual
# Ethnicity                                                     NaN
# Dependents                                                     No
# SurveyLength                                Appropriate in length
# SurveyEase                             Neither easy nor difficult
# Name: 0, Length: 85, dtype: object

# %%
#for row with label 0,2 mainbranch attribute is printed
df.loc[[0,2], 'MainBranch']
# Out:
# 0               I am a student who is learning to code
# 2    I am not primarily a developer, but I write co...
# Name: MainBranch, dtype: object

# %%
#similarly for a particular lable of a row multiple attribute to be printed
df.loc[[0,1], ['MainBranch', 'OpenSourcer']]
# Out:
#                                MainBranch              OpenSourcer
# 0  I am a student who is learning to code                    Never
# 1  I am a student who is learning to code  Less than once per year

# %%
df.Hobbyist
# Out:
# 0        Yes
# 1         No
# 2        Yes
# 3         No
# 4        Yes
#         ...
# 88878    Yes
# 88879     No
# 88880     No
# 88881     No
# 88882    Yes
# Name: Hobbyist, Length: 88883, dtype: object

# %%
#to find answer to solutions
df['Hobbyist'].value_counts()
# Out:
# Hobbyist
# Yes    71257
# No     17626
# Name: count, dtype: int64

# %%
#loc uses index, iloc doesnt
#tried to find a particular solution
df.loc[[0,1,2], 'Hobbyist']
# Out:
# 0    Yes
# 1     No
# 2    Yes
# Name: Hobbyist, dtype: object

# %%
df.loc[0:5, 'Hobbyist':'OrgSize']
#no need to individually enter the answers like above rather slice and enter the values those are required.
# Out:
#   Hobbyist                 OpenSourcer  \
# 0      Yes                       Never
# 1       No     Less than once per year
# 2      Yes                       Never
# 3       No                       Never
# 4      Yes  Once a month or more often
# 5      Yes                       Never
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
# 1  The quality of OSS and closed source software ...
# 2  The quality of OSS and closed source software ...
# 3  The quality of OSS and closed source software ...
# 4  OSS is, on average, of HIGHER quality than pro...
# 5  The quality of OSS and closed source software ...
#
#                                Employment                 Country  \
# 0  Not employed, and not looking for work          United Kingdom
# 1      Not employed, but looking for work  Bosnia and Herzegovina
# 2                      Employed full-time                Thailand
# ...

# %%
df['EdLevel'].value_counts()
# Out:
# EdLevel
# Bachelor’s degree (BA, BS, B.Eng., etc.)                                              39134
# Master’s degree (MA, MS, M.Eng., MBA, etc.)                                           19569
# Some college/university study without earning a degree                                10502
# Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)     8642
# Associate degree                                                                       2938
# Other doctoral degree (Ph.D, Ed.D., etc.)                                              2432
# Primary/elementary school                                                              1422
# Professional degree (JD, MD, etc.)                                                     1198
# I never completed any formal education                                                  553
# Name: count, dtype: int64

# %%
#label and index is the same
df['MainBranch']
# Out:
# 0                   I am a student who is learning to code
# 1                   I am a student who is learning to code
# 2        I am not primarily a developer, but I write co...
# 3                           I am a developer by profession
# 4                           I am a developer by profession
#                                ...
# 88878                                                  NaN
# 88879                                                  NaN
# 88880                                                  NaN
# 88881                                                  NaN
# 88882                                                  NaN
# Name: MainBranch, Length: 88883, dtype: object

# %%
df.set_index('MainBranch')
# Out:
#                                                     Respondent Hobbyist  \
# MainBranch
# I am a student who is learning to code                       1      Yes
# I am a student who is learning to code                       2       No
# I am not primarily a developer, but I write cod...           3      Yes
# I am a developer by profession                               4       No
# I am a developer by profession                               5      Yes
# ...                                                        ...      ...
# NaN                                                      88377      Yes
# NaN                                                      88601       No
# NaN                                                      88802       No
# NaN                                                      88816       No
# NaN                                                      88863      Yes
#
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=88883, step=1)

# %%
filt = (df['Hobbyist']=='Yes')

# %%
df[filt]
#filter data
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 2               3  I am not primarily a developer, but I write co...      Yes
# 4               5                     I am a developer by profession      Yes
# 5               6  I am not primarily a developer, but I write co...      Yes
# 7               8                        I code primarily as a hobby      Yes
# ...           ...                                                ...      ...
# 88872       87739                                                NaN      Yes
# 88875       88182                                                NaN      Yes
# 88877       88282                                                NaN      Yes
# 88878       88377                                                NaN      Yes
# 88882       88863                                                NaN      Yes
#
# ...

# %%
df.loc[filt]
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 2               3  I am not primarily a developer, but I write co...      Yes
# 4               5                     I am a developer by profession      Yes
# 5               6  I am not primarily a developer, but I write co...      Yes
# 7               8                        I code primarily as a hobby      Yes
# ...           ...                                                ...      ...
# 88872       87739                                                NaN      Yes
# 88875       88182                                                NaN      Yes
# 88877       88282                                                NaN      Yes
# 88878       88377                                                NaN      Yes
# 88882       88863                                                NaN      Yes
#
# ...

# %%
df.loc[filt,'MainBranch']
#finding wherever the filter applies and gives the corresponding column answer for that
# Out:
# 0                   I am a student who is learning to code
# 2        I am not primarily a developer, but I write co...
# 4                           I am a developer by profession
# 5        I am not primarily a developer, but I write co...
# 7                              I code primarily as a hobby
#                                ...
# 88872                                                  NaN
# 88875                                                  NaN
# 88877                                                  NaN
# 88878                                                  NaN
# 88882                                                  NaN
# Name: MainBranch, Length: 71257, dtype: object

# %%
high = (df['ConvertedComp']>100000)
df.loc[high, ['Country', 'Hobbyist','Employment']]
# Out:
#               Country Hobbyist          Employment
# 5              Canada      Yes  Employed full-time
# 15     United Kingdom      Yes  Employed full-time
# 21      United States      Yes  Employed full-time
# 25      United States      Yes  Employed full-time
# 31      United States       No  Employed full-time
# ...               ...      ...                 ...
# 88321   United States      Yes  Employed full-time
# 88323   United States      Yes  Employed full-time
# 88324   United States      Yes  Employed full-time
# 88325   United States      Yes  Employed full-time
# 88329     Netherlands      Yes  Employed full-time
#
# [13777 rows x 3 columns]

# %%
df.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource',
#        'Employment', 'Country', 'Student', 'EdLevel', 'UndergradMajor',
#        'EduOther', 'OrgSize', 'DevType', 'YearsCode', 'Age1stCode',
#        'YearsCodePro', 'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney',
#        'MgrWant', 'JobSeek', 'LastHireDate', 'LastInt', 'FizzBuzz',
#        'JobFactors', 'ResumeUpdate', 'CurrencySymbol', 'CurrencyDesc',
#        'CompTotal', 'CompFreq', 'ConvertedComp', 'WorkWeekHrs', 'WorkPlan',
#        'WorkChallenge', 'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev',
#        'CodeRevHrs', 'UnitTests', 'PurchaseHow', 'PurchaseWhat',
#        'LanguageWorkedWith', 'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %%
high = (df['ConvertedComp']>100000)
df.loc[high, ['LanguageDesireNextYear','LanguageWorkedWith','ConvertedComp']]
# Out:
#                                   LanguageDesireNextYear  \
# 5                                       Python;Scala;SQL
# 15     C#;HTML/CSS;JavaScript;TypeScript;WebAssembly;...
# 21     Bash/Shell/PowerShell;C++;HTML/CSS;JavaScript;...
# 25     C#;HTML/CSS;JavaScript;Objective-C;Ruby;SQL;Sw...
# 31     Bash/Shell/PowerShell;HTML/CSS;JavaScript;Pyth...
# ...                                                  ...
# 88321                                                NaN
# 88323                               C#;Java;Kotlin;Scala
# 88324  Bash/Shell/PowerShell;Clojure;HTML/CSS;Java;Ja...
# 88325                   JavaScript;Rust;Scala;TypeScript
# 88329                             C#;Java;JavaScript;PHP
#
#                                       LanguageWorkedWith  ConvertedComp
# 5                                             Java;R;SQL       366420.0
# 15     Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;T...       455352.0
# ...

# %%
#new way of filtering, taking input and doung shit using string method
countries = ['India', 'Canada', 'Kenya']
filt = df['Country'].isin(countries)
df.loc[filt, ['Country', 'Age']]
# Out:
#       Country   Age
# 5      Canada  28.0
# 7       India  24.0
# 9       India   NaN
# 11     Canada  21.0
# 14      India  20.0
# ...       ...   ...
# 88852   India  24.0
# 88853   India   NaN
# 88855  Canada   NaN
# 88864   India  24.0
# 88878  Canada   NaN
#
# [12705 rows x 2 columns]

# %%
df['LanguageWorkedWith']
# Out:
# 0                          HTML/CSS;Java;JavaScript;Python
# 1                                      C++;HTML/CSS;Python
# 2                                                 HTML/CSS
# 3                                      C;C++;C#;Python;SQL
# 4              C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA
#                                ...
# 88878                        HTML/CSS;JavaScript;Other(s):
# 88879                                                  NaN
# 88880                                                  NaN
# 88881                                                  NaN
# 88882    Bash/Shell/PowerShell;HTML/CSS;Java;JavaScript...
# Name: LanguageWorkedWith, Length: 88883, dtype: object

# %%
filt = df['LanguageWorkedWith'].str.contains('Python', na = False)
df.loc[filt,'LanguageWorkedWith']
# Out:
# 0                          HTML/CSS;Java;JavaScript;Python
# 1                                      C++;HTML/CSS;Python
# 3                                      C;C++;C#;Python;SQL
# 4              C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA
# 7        Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
#                                ...
# 88854    Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
# 88860      Bash/Shell/PowerShell;C++;Python;Ruby;Other(s):
# 88865      Bash/Shell/PowerShell;HTML/CSS;Python;Other(s):
# 88872             C;C++;HTML/CSS;JavaScript;PHP;Python;SQL
# 88876                           HTML/CSS;JavaScript;Python
# Name: LanguageWorkedWith, Length: 36443, dtype: object

# %%
filt
# Out:
# 0         True
# 1         True
# 2        False
# 3         True
# 4         True
#          ...
# 88878    False
# 88879    False
# 88880    False
# 88881    False
# 88882    False
# Name: LanguageWorkedWith, Length: 88883, dtype: bool
